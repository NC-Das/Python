# %%
print("nayan")
# Out:
# nayan

# %%
a =  int(input())
b = int(input())
sum = a%10 + b%10
print(sum)
# Out:
# 5

# %%
num = input()
number = num.split()
x= int(number[0])
y=int(number[1])
x_last_digit= x%10
y_last_digit = y%10
print(x_last_digit+y_last_digit)
# Out:
# 5
