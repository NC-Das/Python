# %%
numbers = input()
num = numbers.split()
brightness = int(num[0])
threshold = int(num[1])
if brightness >= threshold:
    print("ON")
else:
    print("OFF")
# Out:
# OFF

# %%
brightness, threshold = filter(int, input().split())

if brightness >= threshold:
    print("ON")
else:
    print("OFF")
# Out:
# ON
